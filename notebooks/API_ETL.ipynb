# %% [markdown]
# ### H&M API ETL

# %%
import requests
import json

# %%
# api request for categories

url = "https://apidojo-hm-hennes-mauritz-v1.p.rapidapi.com/categories/list"

querystring = {"lang":"en","country":"us"}

headers = {
	"X-RapidAPI-Key": "e1f8060bc4msh997975f6a3e3fd7p1fe727jsn074f97cdc837",
	"X-RapidAPI-Host": "apidojo-hm-hennes-mauritz-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'CatName': 'Women', 'CategoryValue': 'ladies', 'CategoriesArray': [{'CatName': 'New Arrivals', 'CategoryValue': 'new-arrivals', 'CategoriesArray': [{'CatName': 'View All', 'CategoryValue': 'view-all', 'tagCodes': ['ladies_newarrivals_all', 'ladies_newarrivals']}, {'CatName': 'Clothes', 'CategoryValue': 'clothes', 'tagCodes': ['ladies_newarrivals_clothes', 'ladies_newarrivals_clothes']}, {'CatName': 'Shoes & Accessories', 'CategoryValue': 'shoes-accessories', 'tagCodes': ['ladies_newarrivals_shoesacc', 'ladies_newarrivals_shoesacc']}, {'CatName': 'Beauty', 'CategoryValue': 'beauty', 'tagCodes': ['beauty_newarrivals_all']}, {'CatName': 'Underwear & Nightwear', 'CategoryValue': 'underwear-nightwear', 'tagCodes': ['ladies_newarrivals_underwear_nightwear', 'ladies_newarrivals_underwear_nightwear']}], 'tagCodes': []}, {'CatName': 'Trending Now', 'CategoryValue': 'seasonal-trending', 'tagCodes': []}, {'CatName': 'Special Offers', 'CategoryValue': 'deals', 'CategoriesArray': [{'CatName': '
# ...

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"CatName":"Women","CategoryValue":"ladies","CategoriesArray":[{"CatName":"New Arrivals","CategoryValue":"new-arrivals","CategoriesArray":[{"CatName":"View All","CategoryValue":"view-all","tagCodes":["ladies_newarrivals_all","ladies_newarrivals"]},{"CatName":"Clothes","CategoryValue":"clothes","tagCodes":["ladies_newarrivals_clothes","ladies_newarrivals_clothes"]},{"CatName":"Shoes & Accessories","CategoryValue":"shoes-accessories","tagCodes":["ladies_newarrivals_shoesacc","ladies_newarrivals_shoesacc"]},{"CatName":"Beauty","CategoryValue":"beauty","tagCodes":["beauty_newarrivals_all"]},{"CatName":"Underwear & Nightwear","CategoryValue":"underwear-nightwear","tagCodes":["ladies_newarrivals_underwear_nightwear","ladies_newarrivals_underwear_nightwear"]}],"tagCodes":[]},{"CatName":"Trending Now","CategoryValue":"seasonal-trending","tagCodes":[]},{"CatName":"Special Offers","CategoryValue":"deals","CategoriesArray":[{"CatName":"Bestsellers","CategoryValue":"bestsellers","tagCodes":["n
# ...

# %%
#str
type(response.text)
# Out:
# str

# %%
#convert to dictionary 
json.loads(response.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 #convert to dictionary
# ----> 2 json.loads(hm_request)
#
# File /opt/anaconda3/lib/python3.11/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not Response

# %%
# list
type(json.loads(response.text))
# Out:
# list

# %%
category_response = json.loads(response.text)

# %%
category_response[1]
# Out:
# {'CatName': 'Divided',
#  'CategoryValue': 'divided',
#  'CategoriesArray': [{'CatName': 'Offers & Deals',
#    'CategoryValue': 'deals',
#    'tagCodes': []},
#   {'CatName': 'New Arrivals',
#    'CategoryValue': 'new-arrivals',
#    'CategoriesArray': [{'CatName': 'Clothes',
#      'CategoryValue': 'clothes',
#      'tagCodes': ['ladies_divided_new_clothes']},
#     {'CatName': 'Shoes & Accessories',
#      'CategoryValue': 'shoes-accessories',
#      'tagCodes': ['ladies_divided_new_accessories']}],
#    'tagCodes': []},
#   {'CatName': 'Shop by Product',
#    'CategoryValue': 'shop-by-product',
#    'CategoriesArray': [{'CatName': 'View All',
#      'CategoryValue': 'view-all',
#      'tagCodes': ['ladies_divided', 'ladies_divided']},
#     {'CatName': 'Dresses',
#      'CategoryValue': 'dresses',
#      'tagCodes': ['ladies_divided_dresses', 'ladies_divided_dresses']},
#     {'CatName': 'Tops',
#      'CategoryValue': 'tops',
# ...

# %%
category_response[0]
# Out:
# {'CatName': 'Women',
#  'CategoryValue': 'ladies',
#  'CategoriesArray': [{'CatName': 'New Arrivals',
#    'CategoryValue': 'new-arrivals',
#    'CategoriesArray': [{'CatName': 'View All',
#      'CategoryValue': 'view-all',
#      'tagCodes': ['ladies_newarrivals_all', 'ladies_newarrivals']},
#     {'CatName': 'Clothes',
#      'CategoryValue': 'clothes',
#      'tagCodes': ['ladies_newarrivals_clothes', 'ladies_newarrivals_clothes']},
#     {'CatName': 'Shoes & Accessories',
#      'CategoryValue': 'shoes-accessories',
#      'tagCodes': ['ladies_newarrivals_shoesacc',
#       'ladies_newarrivals_shoesacc']},
#     {'CatName': 'Beauty',
#      'CategoryValue': 'beauty',
#      'tagCodes': ['beauty_newarrivals_all']},
#     {'CatName': 'Underwear & Nightwear',
#      'CategoryValue': 'underwear-nightwear',
#      'tagCodes': ['ladies_newarrivals_underwear_nightwear',
#       'ladies_newarrivals_underwear_nightwear']}],
#    'tagCodes': []},
#   {'CatName': 'Trending Now',
# ...

# %%
# Using function to check and find dresses element 
def find_dresses(data):
    if 'CategoriesArray' in data:
        for category in data['CategoriesArray']:
            result = find_dresses(category)
            if result:
                return result

    if data.get('CatName') == 'Dresses':
        return data 

    return None 

dresses_info = find_dresses(category_response[0])
print(dresses_info)
# Out:
# {'CatName': 'Dresses', 'CategoryValue': 'dresses', 'CategoriesArray': [{'CatName': 'Long Sleeve', 'CategoryValue': 'long-sleeved-dresses', 'tagCodes': ['ladies_plus_dresses_longsleeved', 'ladies_plus_dresses_longsleeved']}], 'tagCodes': ['ladies_plus_dresses', 'ladies_plus_dresses']}

# %%
# Navigate to dresses using indexes
dresses = category_response[0]['CategoriesArray'][3]['CategoriesArray'][2]['CategoriesArray'][3]
# Out:
# {'CatName': 'Dresses',
#  'CategoryValue': 'dresses',
#  'tagCodes': ['ladies_premium_selection_dresses',
#   'ladies_premium_selection_dresses']}

# %%
#product details api request 
url = "https://apidojo-hm-hennes-mauritz-v1.p.rapidapi.com/products/detail"

querystring = {"lang":"en","country":"us","productcode":"0839915011"}

headers = {
	"X-RapidAPI-Key": "e1f8060bc4msh997975f6a3e3fd7p1fe727jsn074f97cdc837",
	"X-RapidAPI-Host": "apidojo-hm-hennes-mauritz-v1.p.rapidapi.com"
}

product_request = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'CatName': 'Women', 'CategoryValue': 'ladies', 'CategoriesArray': [{'CatName': 'New Arrivals', 'CategoryValue': 'new-arrivals', 'CategoriesArray': [{'CatName': 'View All', 'CategoryValue': 'view-all', 'tagCodes': ['ladies_newarrivals_all', 'ladies_newarrivals']}, {'CatName': 'Clothes', 'CategoryValue': 'clothes', 'tagCodes': ['ladies_newarrivals_clothes', 'ladies_newarrivals_clothes']}, {'CatName': 'Shoes & Accessories', 'CategoryValue': 'shoes-accessories', 'tagCodes': ['ladies_newarrivals_shoesacc', 'ladies_newarrivals_shoesacc']}, {'CatName': 'Beauty', 'CategoryValue': 'beauty', 'tagCodes': ['beauty_newarrivals_all']}, {'CatName': 'Underwear & Nightwear', 'CategoryValue': 'underwear-nightwear', 'tagCodes': ['ladies_newarrivals_underwear_nightwear', 'ladies_newarrivals_underwear_nightwear']}], 'tagCodes': []}, {'CatName': 'Trending Now', 'CategoryValue': 'seasonal-trending', 'tagCodes': []}, {'CatName': 'Special Offers', 'CategoryValue': 'deals', 'CategoriesArray': [{'CatName': '
# ...

# %%
json.loads(product_request.text)
# Out:
# {'responseStatusCode': 'ok',
#  'product': {'code': '0839915011',
#   'name': 'Slim Fit Suit Vest',
#   'description': 'Slim-fit suit vest in woven fabric with back in shiny, woven fabric. Buttons at front, a chest pocket, and welt front pockets. Adjustable tab at back. Fitted silhouette. Lined.',
#   'sapProductName': 'Dave Waistcoat',
#   'sellingAttributes': [],
#   'color': {'code': '08', 'text': 'Dark gray', 'rgbColor': '#494A4F'},
#   'whitePrice': {'price': 31.99,
#    'currency': 'USD',
#    'referenceFlag': True,
#    'startDate': 1707087600000,
#    'endDate': 32503676400000},
#   'redPrice': {'price': 10.99,
#    'currency': 'USD',
#    'referenceFlag': False,
#    'startDate': 1607295600000,
#    'endDate': 32503676400000},
#   'priceType': 'SALES_PRICE',
#   'measurements': ['Back: Length: 23 in (Size 42R)',
#    'Shoulder: Width: 14 in (Size 42R)'],
#   'assortmentTypeKey': 'clothing',
#   'lengthCollection': [{'code': 'garmentLength', 'value': ['Regular length']},
# ...

# %%
product_response = json.loads(product_request.text)

# %%
product_response['product']
# Out:
# {'code': '0839915011',
#  'name': 'Slim Fit Suit Vest',
#  'description': 'Slim-fit suit vest in woven fabric with back in shiny, woven fabric. Buttons at front, a chest pocket, and welt front pockets. Adjustable tab at back. Fitted silhouette. Lined.',
#  'sapProductName': 'Dave Waistcoat',
#  'sellingAttributes': [],
#  'color': {'code': '08', 'text': 'Dark gray', 'rgbColor': '#494A4F'},
#  'whitePrice': {'price': 31.99,
#   'currency': 'USD',
#   'referenceFlag': True,
#   'startDate': 1707087600000,
#   'endDate': 32503676400000},
#  'redPrice': {'price': 10.99,
#   'currency': 'USD',
#   'referenceFlag': False,
#   'startDate': 1607295600000,
#   'endDate': 32503676400000},
#  'priceType': 'SALES_PRICE',
#  'measurements': ['Back: Length: 23 in (Size 42R)',
#   'Shoulder: Width: 14 in (Size 42R)'],
#  'assortmentTypeKey': 'clothing',
#  'lengthCollection': [{'code': 'garmentLength', 'value': ['Regular length']},
#   {'code': 'sleeveLength', 'value': ['Sleeveless']}],
# ...

# %%
# extract color
product_response['product']['color']['text']
# Out:
# 'Dark gray'

# %%
#extract price
product_response['product']['whitePrice']['price']
# Out:
# 31.99

# %%
#extract name
product_response['product']['name']
# Out:
# 'Slim Fit Suit Vest'

# %%
products = product_response['product']

# %%
type(products)
# Out:
# dict

# %%
# looping through products and extracting product details 
products_data = {
    'name':[],
    'price':[],
    'color':[]
}
counter = 0

for product in products:
    if counter < 100:
        name = product['name']
        products_data['name'].append(name)
        print(name)
        
        price = product['whitePrice']['price']
        products_data['price'].append(price)
        print(price)
        
        color = product['color']['text']
        products_data['color'].append(color)
        print(color)
        print('-'*75)

        counter += 1  
    else:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 11
#       9 for product in products:
#      10     if counter < 100:
# ---> 11         name = product['name']
#      12         products_data['name'].append(name)
#      13         print(name)
#
# TypeError: string indices must be integers, not 'str'

# %%
#convert products_data to pandas dataframe
hm_df = pd.DataFrame(products_data)

# %%
# check out dataframe
hm_df.head()

# %%
#save dataframe to csv file
hm_df.to_csv('hm_products.csv', index=False)

# %%
# connect to yelp database on the MySQL server running on lmu.build
engine = create_engine('mysql+mysqldb://florebr_dba:Zoey2001@floresbree.lmu.build/floresbr_RevolveJob')

# %%
#save df onto sql database
hm_df.to_sql('hm', engine, if_exists='replace',index=False)
